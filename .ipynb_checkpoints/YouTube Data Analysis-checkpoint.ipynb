# %% [markdown]
# Google API Python Client is a client library for accessing Google's APIs.

# %%
pip install --upgrade google-api-python-client
# Out:
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.125.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting httplib2<1.dev0,>=0.19.0 (from google-api-python-client)
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 (from google-api-python-client)
#   Downloading google_auth-2.29.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client)
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 (from google-api-python-client)
#   Downloading google_api_core-2.18.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client)
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client)
#   Downloading googleapis_common_protos-1.63.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client)
#   Downloading protobuf-4.25.3-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client)
#   Downloading proto_plus-1.23.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\adity\data-anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client)
#   Downloading cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\adity\data-anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client)
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\adity\data-anaconda3\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\adity\data-anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\adity\data-anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\adity\data-anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\adity\data-anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\adity\data-anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.7.22)
# Downloading google_api_python_client-2.125.0-py2.py3-none-any.whl (12.5 MB)
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#     --------------------------------------- 0.2/12.5 MB 4.1 MB/s eta 0:00:03
#    --- ------------------------------------ 1.0/12.5 MB 12.9 MB/s eta 0:00:01
#    ------- -------------------------------- 2.4/12.5 MB 19.1 MB/s eta 0:00:01
#    ------------ --------------------------- 3.8/12.5 MB 24.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.5/12.5 MB 27.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.3/12.5 MB 30.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.0/12.5 MB 32.0 MB/s eta 0:00:01
#    --------------------------------- ------ 10.6/12.5 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.5 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.5/12.5 MB 38.4 MB/s eta 0:00:00
# Downloading google_api_core-2.18.0-py3-none-any.whl (138 kB)
#    ---------------------------------------- 0.0/138.3 kB ? eta -:--:--
#    ---------------------------------------- 138.3/138.3 kB 8.0 MB/s eta 0:00:00
# Downloading google_auth-2.29.0-py2.py3-none-any.whl (189 kB)
#    ---------------------------------------- 0.0/189.2 kB ? eta -:--:--
#    --------------------------------------- 189.2/189.2 kB 11.9 MB/s eta 0:00:00
# Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#    ---------------------------------------- 0.0/96.9 kB ? eta -:--:--
#    ---------------------------------------- 96.9/96.9 kB ? eta 0:00:00
# Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Downloading cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Downloading googleapis_common_protos-1.63.0-py2.py3-none-any.whl (229 kB)
#    ---------------------------------------- 0.0/229.1 kB ? eta -:--:--
#    --------------------------------------- 229.1/229.1 kB 13.7 MB/s eta 0:00:00
# Downloading proto_plus-1.23.0-py3-none-any.whl (48 kB)
#    ---------------------------------------- 0.0/48.8 kB ? eta -:--:--
#    ---------------------------------------- 48.8/48.8 kB 2.6 MB/s eta 0:00:00
# Downloading protobuf-4.25.3-cp310-abi3-win_amd64.whl (413 kB)
#    ---------------------------------------- 0.0/413.4 kB ? eta -:--:--
#    --------------------------------------- 413.4/413.4 kB 26.9 MB/s eta 0:00:00
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Installing collected packages: uritemplate, rsa, protobuf, httplib2, cachetools, proto-plus, googleapis-common-protos, google-auth, google-auth-httplib2, google-api-core, google-api-python-client
# Successfully installed cachetools-5.3.3 google-api-core-2.18.0 google-api-python-client-2.125.0 google-auth-2.29.0 google-auth-httplib2-0.2.0 googleapis-common-protos-1.63.0 httplib2-0.22.0 proto-plus-1.23.0 protobuf-4.25.3 rsa-4.9 uritemplate-4.1.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# This is Google Auth library for Python, which provides tools for managing authentication with Google APIs.

# %%
pip install --upgrade google-auth-oauthlib google-auth-httplib2
# Out:
# Collecting google-auth-oauthlibNote: you may need to restart the kernel to use updated packages.
#
#   Downloading google_auth_oauthlib-1.2.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: google-auth-httplib2 in c:\users\adity\data-anaconda3\lib\site-packages (0.2.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\adity\data-anaconda3\lib\site-packages (from google-auth-oauthlib) (2.29.0)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: httplib2>=0.19.0 in c:\users\adity\data-anaconda3\lib\site-packages (from google-auth-httplib2) (0.22.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\adity\data-anaconda3\lib\site-packages (from google-auth>=2.15.0->google-auth-oauthlib) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\adity\data-anaconda3\lib\site-packages (from google-auth>=2.15.0->google-auth-oauthlib) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\adity\data-anaconda3\lib\site-packages (from google-auth>=2.15.0->google-auth-oauthlib) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\adity\data-anaconda3\lib\site-packages (from httplib2>=0.19.0->google-auth-httplib2) (3.0.9)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib)
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\users\adity\data-anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.31.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\adity\data-anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-auth-oauthlib) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\adity\data-anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\adity\data-anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\adity\data-anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\adity\data-anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2023.7.22)
# Downloading google_auth_oauthlib-1.2.0-py2.py3-none-any.whl (24 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#    ---------------------------------------- 0.0/151.7 kB ? eta -:--:--
#    ------------------------------------- -- 143.4/151.7 kB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 151.7/151.7 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: oauthlib, requests-oauthlib, google-auth-oauthlib
# Successfully installed google-auth-oauthlib-1.2.0 oauthlib-3.2.2 requests-oauthlib-2.0.0

# %% [markdown]
# Import necessary library

# %%
from googleapiclient.discovery import build
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# If you Don't have account on google cloud consol. then you need to create one account to generate a youtube API.
#
# The YouTube Data API v3 is an API that provides access to YouTube data, such as videos, playlists, and channels.
#
# Using the "build" function from the googleapiclient.discovery module to create a service object for interacting with the YouTube Data API.

# %%
api_key = "Insert_Generated_YouTube_API" # YouTube Data API v3
channel_id=["UC9FjY3LlnBSirhA_Xyxq14g",             # A list of YouTube Channel ids
            "UCc5TAfTiVRknqA4bxGlWKFg",
            "UC-7fYi9vE6H0XpWzZ8lT4KQ",
            "UCnz-ZXXER4jOvuED5trXfEA",
            "UCBwmMxybNva6P_5VmxjzwqA",
            "UC0T6MVd3wQDB5ICAe45OxaQ",
            "UC6WzPg6yxF9dQx2_O6R4lww",
            "UCBGOUQHNNtNGcGzVq5rIXjw",
            "UCbTggJVf0NDTfWX-C_gUGSg",
            "UCPQQtbAN6z7NEjW4sRAT-yQ",
            "UCoKvdSR1Xhol5eGl1Wn1VgA",
            "UCrHDY6lrJ8NXCKxFppomr3A",
            "UChYs-_zjKRYhdMddjx-NPLw",
            "UCUicT5osQLEL11TimsC8I1g",
            "UCaxaxcoyql4RWgfFraZzL1Q"
           ]

youtube=build('youtube','v3', developerKey=api_key) # Build Function

# %% [markdown]
# Function to get channel statistics such as snippet,contentDetails,statistics.

# %%
def get_channel_stats(youtube, channel_id):

    request = youtube.channels().list(part='snippet,contentDetails,statistics',id=','.join(channel_id))
    
    response = request.execute()
    
    #print(response)
    
    all_data=[]
    for i in range(len(response['items'])):
        data = dict(Channel_id=response['items'][i]['id'],
            Channel_name = response['items'][i]['snippet']['title'],
            Channel_Started=response['items'][i]['snippet']['publishedAt'],
            Subscribers=response['items'][i]['statistics'].get('subscriberCount'),
            TotalViews=response['items'][i]['statistics'].get('viewCount'),
            TotalUploadedVideos=response['items'][i]['statistics'].get('videoCount'),
            Custom_url= response['items'][i]['snippet'].get('customUrl'),
            Country=response['items'][i]['snippet'].get('country'))
        all_data.append(data)
    
    return all_data

# %% [markdown]
# Calling "get_channel_stats" function to get channel statistics and saving in "youtube_data" variable

# %%
youtube_data=get_channel_stats(youtube, channel_id)

# %%
print(youtube_data) #It is in the form of List(dict)
# Out:
# [{'Channel_id': 'UCaxaxcoyql4RWgfFraZzL1Q', 'Channel_name': 'Nancy Solanki', 'Channel_Started': '2023-03-10T12:18:40.189285Z', 'Subscribers': '7320', 'TotalViews': '250403', 'TotalUploadedVideos': '71', 'Custom_url': '@thecatalystgirl', 'Country': 'IN'}, {'Channel_id': 'UCnz-ZXXER4jOvuED5trXfEA', 'Channel_name': 'techTFQ', 'Channel_Started': '2020-06-13T05:20:37.182391Z', 'Subscribers': '286000', 'TotalViews': '15582354', 'TotalUploadedVideos': '134', 'Custom_url': '@techtfq', 'Country': 'MY'}, {'Channel_id': 'UCUicT5osQLEL11TimsC8I1g', 'Channel_name': 'Ashish Pratap Singh', 'Channel_Started': '2013-05-18T04:46:00Z', 'Subscribers': '43600', 'TotalViews': '2798357', 'TotalUploadedVideos': '28', 'Custom_url': '@ashishps_1', 'Country': 'IN'}, {'Channel_id': 'UC0T6MVd3wQDB5ICAe45OxaQ', 'Channel_name': 'WsCube Tech', 'Channel_Started': '2015-08-22T13:22:51Z', 'Subscribers': '3280000', 'TotalViews': '274385977', 'TotalUploadedVideos': '5156', 'Custom_url': '@wscubetech', 'Country': 'IN'}, {'Channel_id': 'UCrHDY6lrJ8NXCKxFppomr3A', 'Channel_name': 'Learn More', 'Channel_Started': '2016-12-12T05:00:55Z', 'Subscribers': '2140000', 'TotalViews': '118055809', 'TotalUploadedVideos': '786', 'Custom_url': '@learn_more_pro', 'Country': 'IN'}, {'Channel_id': 'UC9FjY3LlnBSirhA_Xyxq14g', 'Channel_name': 'Weekend India', 'Channel_Started': '2022-03-16T22:09:57.246468Z', 'Subscribers': '78300', 'TotalViews': '11487249', 'TotalUploadedVideos': '209', 'Custom_url': '@weekendindia', 'Country': 'IN'}, {'Channel_id': 'UCPQQtbAN6z7NEjW4sRAT-yQ', 'Channel_name': 'RunCodes', 'Channel_Started': '2016-11-16T14:52:31Z', 'Subscribers': '23200', 'TotalViews': '4564357', 'TotalUploadedVideos': '163', 'Custom_url': '@runcodes', 'Country': 'US'}, {'Channel_id': 'UCBGOUQHNNtNGcGzVq5rIXjw', 'Channel_name': 'Kunal Kushwaha', 'Channel_Started': '2020-05-09T20:35:27.233665Z', 'Subscribers': '589000', 'TotalViews': '37037863', 'TotalUploadedVideos': '546', 'Custom_url': '@kunalkushwaha', 'Country': 'IN'}, {'Channel_id': 'UC6WzPg6yxF9dQx2_O6R4lww', 'Channel_name': 'Nitish Rajput', 'Channel_Started': '2020-04-29T17:18:25.574824Z', 'Subscribers': '4050000', 'TotalViews': '373667410', 'TotalUploadedVideos': '99', 'Custom_url': '@nitishrajput', 'Country': 'IN'}, {'Channel_id': 'UChYs-_zjKRYhdMddjx-NPLw', 'Channel_name': 'Singh in USA', 'Channel_Started': '2013-09-05T01:15:06Z', 'Subscribers': '1110000', 'TotalViews': '249056691', 'TotalUploadedVideos': '864', 'Custom_url': '@singhinusa', 'Country': 'US'}, {'Channel_id': 'UCbTggJVf0NDTfWX-C_gUGSg', 'Channel_name': 'Sumit Mittal', 'Channel_Started': '2018-01-16T15:55:22Z', 'Subscribers': '105000', 'TotalViews': '3920534', 'TotalUploadedVideos': '241', 'Custom_url': '@sumitmittal07', 'Country': 'IN'}, {'Channel_id': 'UCBwmMxybNva6P_5VmxjzwqA', 'Channel_name': 'Apna College', 'Channel_Started': '2020-08-05T16:09:28.304314Z', 'Subscribers': '5130000', 'TotalViews': '793733200', 'TotalUploadedVideos': '819', 'Custom_url': '@apnacollegeofficial', 'Country': None}, {'Channel_id': 'UCoKvdSR1Xhol5eGl1Wn1VgA', 'Channel_name': 'MistrAI', 'Channel_Started': '2023-11-24T21:56:18.571502Z', 'Subscribers': '1340', 'TotalViews': '48218', 'TotalUploadedVideos': '29', 'Custom_url': '@mistrai259k', 'Country': None}, {'Channel_id': 'UCc5TAfTiVRknqA4bxGlWKFg', 'Channel_name': 'Tekno UF', 'Channel_Started': '2023-02-11T05:55:01.369504Z', 'Subscribers': '4200', 'TotalViews': '618806', 'TotalUploadedVideos': '543', 'Custom_url': '@teknouf', 'Country': 'IN'}]

# %% [markdown]
# Create a DataFrame with youtube_data

# %%
df=pd.DataFrame(youtube_data)

# %% [markdown]
# Find the dimensionality of the DataFrame

# %%
df.shape
# Out:
# (14, 8)

# %% [markdown]
# Display the first five rows of the DataFrame and try to observe Data.

# %%
df.head()
# Out:
#                  Channel_id         Channel_name              Channel_Started  \
# 0  UCaxaxcoyql4RWgfFraZzL1Q        Nancy Solanki  2023-03-10T12:18:40.189285Z
# 1  UCnz-ZXXER4jOvuED5trXfEA              techTFQ  2020-06-13T05:20:37.182391Z
# 2  UCUicT5osQLEL11TimsC8I1g  Ashish Pratap Singh         2013-05-18T04:46:00Z
# 3  UC0T6MVd3wQDB5ICAe45OxaQ          WsCube Tech         2015-08-22T13:22:51Z
# 4  UCrHDY6lrJ8NXCKxFppomr3A           Learn More         2016-12-12T05:00:55Z
#
#   Subscribers TotalViews TotalUploadedVideos        Custom_url Country
# 0        7320     250403                  71  @thecatalystgirl      IN
# 1      286000   15582354                 134          @techtfq      MY
# 2       43600    2798357                  28       @ashishps_1      IN
# 3     3280000  274385977                5156       @wscubetech      IN
# 4     2140000  118055809                 786   @learn_more_pro      IN

# %% [markdown]
# The info() method in pandas use to see a concise summary of the DataFrame, including the column names, data types, and memory usage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Channel_id           14 non-null     object
#  1   Channel_name         14 non-null     object
#  2   Channel_Started      14 non-null     object
#  3   Subscribers          14 non-null     object
#  4   TotalViews           14 non-null     object
#  5   TotalUploadedVideos  14 non-null     object
#  6   Custom_url           14 non-null     object
#  7   Country              12 non-null     object
# dtypes: object(8)
# memory usage: 1.0+ KB

# %% [markdown]
# Update the Columns to required datatype and format

# %%
df['Subscribers']=pd.to_numeric(df['Subscribers'])
df['TotalViews']=pd.to_numeric(df['TotalViews'])
df['TotalUploadedVideos']=pd.to_numeric(df['TotalUploadedVideos'])
df["Channel_Started"] = pd.to_datetime(df["Channel_Started"], format="mixed").dt.date

# %%
df.head()
# Out:
#                  Channel_id         Channel_name Channel_Started  Subscribers  \
# 0  UCaxaxcoyql4RWgfFraZzL1Q        Nancy Solanki      2023-03-10         7320
# 1  UCnz-ZXXER4jOvuED5trXfEA              techTFQ      2020-06-13       286000
# 2  UCUicT5osQLEL11TimsC8I1g  Ashish Pratap Singh      2013-05-18        43600
# 3  UC0T6MVd3wQDB5ICAe45OxaQ          WsCube Tech      2015-08-22      3280000
# 4  UCrHDY6lrJ8NXCKxFppomr3A           Learn More      2016-12-12      2140000
#
#    TotalViews  TotalUploadedVideos        Custom_url Country
# 0      250403                   71  @thecatalystgirl      IN
# 1    15582354                  134          @techtfq      MY
# 2     2798357                   28       @ashishps_1      IN
# 3   274385977                 5156       @wscubetech      IN
# 4   118055809                  786   @learn_more_pro      IN

# %%
df.dtypes
# Out:
# Channel_id             object
# Channel_name           object
# Channel_Started        object
# Subscribers             int64
# TotalViews              int64
# TotalUploadedVideos     int64
# Custom_url             object
# Country                object
# dtype: object

# %% [markdown]
# The format of "Channel_Started" has changed but data type is not. to change column "Channel_Started" to datetime data type

# %%
df["Channel_Started"] = pd.to_datetime(df["Channel_Started"])

# %%
df.dtypes
# Out:
# Channel_id                     object
# Channel_name                   object
# Channel_Started        datetime64[ns]
# Subscribers                     int64
# TotalViews                      int64
# TotalUploadedVideos             int64
# Custom_url                     object
# Country                        object
# dtype: object

# %% [markdown]
# Now, The DataFrame is Ready for Visualize

# %% [markdown]
# Lets check the Channel Popularity Based on Subscribers:

# %%
df['SubscriberPercentage'] = (df['Subscribers'] / df['Subscribers'].sum()) * 100
df = df.sort_values(by='SubscriberPercentage', ascending=False)

plt.figure(figsize=(10, 8))
plt.pie(df['SubscriberPercentage'], labels=df['Channel_name'], autopct='%1.1f%%', startangle=140)
plt.title('Percentage of Subscribers for Each Channel')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

plt.show()

# %% [markdown]
# Apna College has 30.4% of Subscribers of the total DataSet.

# %%
plt.figure(figsize=(25, 8))
ax = sns.barplot(x='Channel_name',y='Subscribers',data=df)

# %% [markdown]
# Insight: The most popular channel in the current Dataset is Apna College.

# %% [markdown]
# But I can't tell about least popular channel. So I have Added subscriber count on each bar

# %%
plt.figure(figsize=(25,8))
sns.barplot(x='Channel_name', y='Subscribers', data=df)

for index, value in enumerate(df['Subscribers']):
    plt.text(index, value, str(value), ha='center', va='bottom') 
    
plt.show()

# %% [markdown]
# Insight: The most popular channel in the current dataframe is Apna College with 5120000 Subscribes and The least popular channel in the current dataframe is MistrAI with 1330 Subscribes.

# %% [markdown]
# Total Views on Channels:

# %%
df['ViewsPercentage'] = (df['TotalViews'] / df['TotalViews'].sum()) * 100

plt.figure(figsize=(10, 8))
plt.pie(df['ViewsPercentage'], labels=df['Channel_name'], autopct='%1.1f%%', startangle=140)
plt.title('Percentage of Views for Each Channel')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

plt.show()

# %% [markdown]
# Only Apna College has 42.1% of the total Viewership.

# %%
plt.figure(figsize=(25, 8))
ax = sns.barplot(x='Channel_name',y='TotalViews',data=df)

for index, value in enumerate(df['TotalViews']):
    plt.text(index, value, str(value), ha='center', va='bottom') 
    
plt.show()

# %% [markdown]
# Insight: The most watched channel is Apna College, with 793,733,200 views, while the least watched channel is MistrAI, with only 48,218 views.

# %% [markdown]
# In this dataset, Apna College emerges as the most popular channel, boasting 5,120,000 subscribers, while MistrAI ranks as the least popular with only 1330 subscribers. As measured by subscriber count and viewership, Channels with larger subscriber bases tend to attract more views, likely due to a built-in audience who actively engages with their content. On the other hand, channels with fewer subscribers may struggle to gain visibility and traction, resulting in lower view counts.

# %%
df
# Out:
#                   Channel_id         Channel_name Channel_Started  \
# 11  UCBwmMxybNva6P_5VmxjzwqA         Apna College      2020-08-05
# 8   UC6WzPg6yxF9dQx2_O6R4lww        Nitish Rajput      2020-04-29
# 3   UC0T6MVd3wQDB5ICAe45OxaQ          WsCube Tech      2015-08-22
# 4   UCrHDY6lrJ8NXCKxFppomr3A           Learn More      2016-12-12
# 9   UChYs-_zjKRYhdMddjx-NPLw         Singh in USA      2013-09-05
# 7   UCBGOUQHNNtNGcGzVq5rIXjw       Kunal Kushwaha      2020-05-09
# 1   UCnz-ZXXER4jOvuED5trXfEA              techTFQ      2020-06-13
# 10  UCbTggJVf0NDTfWX-C_gUGSg         Sumit Mittal      2018-01-16
# 5   UC9FjY3LlnBSirhA_Xyxq14g        Weekend India      2022-03-16
# 2   UCUicT5osQLEL11TimsC8I1g  Ashish Pratap Singh      2013-05-18
# 6   UCPQQtbAN6z7NEjW4sRAT-yQ             RunCodes      2016-11-16
# 0   UCaxaxcoyql4RWgfFraZzL1Q        Nancy Solanki      2023-03-10
# 13  UCc5TAfTiVRknqA4bxGlWKFg             Tekno UF      2023-02-11
# 12  UCoKvdSR1Xhol5eGl1Wn1VgA              MistrAI      2023-11-24
#
#     Subscribers  TotalViews  TotalUploadedVideos            Custom_url  \
# 11      5130000   793733200                  819  @apnacollegeofficial
# 8       4050000   373667410                   99         @nitishrajput
# 3       3280000   274385977                 5156           @wscubetech
# 4       2140000   118055809                  786       @learn_more_pro
# 9       1110000   249056691                  864           @singhinusa
# 7        589000    37037863                  546        @kunalkushwaha
# 1        286000    15582354                  134              @techtfq
# 10       105000     3920534                  241        @sumitmittal07
# 5         78300    11487249                  209         @weekendindia
# 2         43600     2798357                   28           @ashishps_1
# 6         23200     4564357                  163             @runcodes
# 0          7320      250403                   71      @thecatalystgirl
# 13         4200      618806                  543              @teknouf
# 12         1340       48218                   29          @mistrai259k
#
#    Country  SubscriberPercentage  ViewsPercentage  Year
# 11    None             30.448790        42.103233  2020
# 8       IN             24.038519        19.821026  2020
# 3       IN             19.468232        14.554685  2015
# 4       IN             12.701835         6.262219  2016
# 9       US              6.588335        13.211104  2013
# 7       IN              3.495972         1.964657  2020
# 1       MY              1.697535         0.826559  2020
# 10      IN              0.623221         0.207963  2018
# 5       IN              0.464745         0.609336  2022
# 2       IN              0.258785         0.148438  2013
# 6       US              0.137702         0.242114  2016
# 0       IN              0.043447         0.013283  2023
# 13      IN              0.024929         0.032824  2023
# 12    None              0.007953         0.002558  2023

# %%
df['Year'] = df['Channel_Started'].dt.year

channels_per_year = df.groupby('Year').size().reset_index(name='Number of Channels')

print(channels_per_year)

plt.figure(figsize=(12, 6))
ax = sns.barplot(x='Year', y='Number of Channels', data=channels_per_year)

for index, value in enumerate(channels_per_year['Number of Channels']):
    plt.text(index, value, str(value), ha='center', va='bottom')

plt.title('Number of Channels Created Each Year')
plt.xlabel('Year')
plt.ylabel('Number of Channels Created')
plt.grid(True)
plt.show()
# Out:
#    Year  Number of Channels
# 0  2013                   2
# 1  2015                   1
# 2  2016                   2
# 3  2018                   1
# 4  2020                   4
# 5  2022                   1
# 6  2023                   3

# %% [markdown]
# Insight: The data shows the highest channel creation activity in 2020 and 2023

# %%
df['Country'] = df['Country'].fillna('CountryNotDef') #Channels which do not mention the country in their channel(None)

channels_per_country = df.groupby('Country').size().reset_index(name='Number of Channels')

print(channels_per_country)

plt.figure(figsize=(12, 6))
ax = sns.barplot(x='Country', y='Number of Channels', data=channels_per_country)

for index, value in enumerate(channels_per_country['Number of Channels']):
    plt.text(index, value, str(value), ha='center', va='bottom')

plt.title('Number of Channels Created by Country')
plt.xlabel('Year')
plt.ylabel('Number of Channels Created')
plt.grid(True)
plt.show()
# Out:
#          Country  Number of Channels
# 0  CountryNotDef                   2
# 1             IN                   9
# 2             MY                   1
# 3             US                   2

# %% [markdown]
# Insight: The data shows the highest number of channels created in IN (India).
